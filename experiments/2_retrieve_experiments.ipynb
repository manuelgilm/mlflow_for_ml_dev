# %% [markdown]
# # MLflow Experiments
#
# While MLflow does provide a default experiment, it primarily serves as a ‘catch-all’ safety net for runs initiated without a specified active experiment. However, it’s not recommended for regular use. Instead, creating unique experiments for specific collections of runs offers numerous advantages.

# %%
from mlflow_for_ml_dev.utils.utils import get_root_project
import mlflow

# %%
artifact_location = get_root_project() / "experiments" / "mlruns"

mlflow.set_tracking_uri(artifact_location.as_uri())
print(artifact_location)
# Out:
# C:\Users\manue\projects\mlflow_for_ml_dev\experiments\mlruns

# %%
experiment_name = "02-mlflow_experiment_management"
tags = {"project_name":"UNKNOWN", "topic":"experiment_management"}
experiment_id = mlflow.create_experiment(experiment_name, tags=tags)
experiment = mlflow.set_experiment(experiment_name)

# %%
print(f"Name: {experiment.name}")
print(f"Artifact Location: {experiment.artifact_location}")
print(f"Tags: {experiment.tags}")
print(f"Lifecycle_stage: {experiment.lifecycle_stage}")
print(f"Creation timestamp: {experiment.creation_time}")
# Out:
# Name: 02-mlflow_experiment_management
# Artifact Location: file:///C:/Users/manue/projects/mlflow_for_ml_dev/experiments/mlruns/410906214185789992
# Tags: {'project_name': 'UNKNOWN', 'topic': 'experiment_management'}
# Lifecycle_stage: active
# Creation timestamp: 1720966276150

# %% [markdown]
# ## Retrieving Experiments

# %% [markdown]
# ### Get Experiment
#
# `get_experiment(experiment_id: str) → Experiment`
#
# Retrieve an experiment by experiment_id from the backend store
#
# Parameters:
#
# * experiment_id – The experiment ID returned from create_experiment.
#
# Returns:
#
# * mlflow.entities.Experiment

# %%
experiment = mlflow.get_experiment(experiment_id=experiment.experiment_id)

# %%
print(f"Name: {experiment.name}")
print(f"Artifact Location: {experiment.artifact_location}")
print(f"Tags: {experiment.tags}")
print(f"Lifecycle_stage: {experiment.lifecycle_stage}")
print(f"Creation timestamp: {experiment.creation_time}")
# Out:
# Name: 02-mlflow_experiment_management
# Artifact Location: file:///C:/Users/manue/projects/mlflow_for_ml_dev/experiments/mlruns/410906214185789992
# Tags: {'project_name': 'UNKNOWN', 'topic': 'experiment_management'}
# Lifecycle_stage: active
# Creation timestamp: 1720966276150

# %%
experiment = mlflow.get_experiment(experiment_id=experiment.experiment_id+"3")
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 experiment = mlflow.get_experiment(experiment_id=experiment.experiment_id+"3")
#
# File c:\Users\manue\projects\mlflow_for_ml_dev\.venv\Lib\site-packages\mlflow\tracking\fluent.py:1523, in get_experiment(experiment_id)
#    1492 def get_experiment(experiment_id: str) -> Experiment:
#    1493     """Retrieve an experiment by experiment_id from the backend store
#    1494
#    1495     Args:
#    (...)
#    1521         Creation timestamp: 1662004217511
#    1522     """
# -> 1523     return MlflowClient().get_experiment(experiment_id)
#
# File c:\Users\manue\projects\mlflow_for_ml_dev\.venv\Lib\site-packages\mlflow\tracking\client.py:1196, in MlflowClient.get_experiment(self, experiment_id)
#    1164 def get_experiment(self, experiment_id: str) -> Experiment:
#    1165     """Retrieve an experiment by experiment_id from the backend store
#    1166
#    1167     Args:
#    (...)
#    1194       Lifecycle_stage: active
#    1195     """
# -> 1196     return self._tracking_client.get_experiment(experiment_id)
#
# File c:\Users\manue\projects\mlflow_for_ml_dev\.venv\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:471, in TrackingServiceClient.get_experiment(self, experiment_id)
#     463 def get_experiment(self, experiment_id):
#     464     """
#     465     Args:
#     466         experiment_id: The experiment ID returned from ``create_experiment``.
#    (...)
#     469         :py:class:`mlflow.entities.Experiment`
#     470     """
# --> 471     return self.store.get_experiment(experiment_id)
#
# File c:\Users\manue\projects\mlflow_for_ml_dev\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py:434, in FileStore.get_experiment(self, experiment_id)
#     423 """
#     424 Fetch the experiment.
#     425 Note: This API will search for active as well as deleted experiments.
#    (...)
#     431     A single Experiment object if it exists, otherwise raises an Exception.
#     432 """
#     433 experiment_id = FileStore.DEFAULT_EXPERIMENT_ID if experiment_id is None else experiment_id
# --> 434 experiment = self._get_experiment(experiment_id)
#     435 if experiment is None:
#     436     raise MlflowException(
#     437         f"Experiment '{experiment_id}' does not exist.",
#     438         databricks_pb2.RESOURCE_DOES_NOT_EXIST,
#     439     )
#
# File c:\Users\manue\projects\mlflow_for_ml_dev\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py:404, in FileStore._get_experiment(self, experiment_id, view_type)
#     402 experiment_dir = self._get_experiment_path(experiment_id, view_type)
#     403 if experiment_dir is None:
# --> 404     raise MlflowException(
#     405         f"Could not find experiment with ID {experiment_id}",
#     406         databricks_pb2.RESOURCE_DOES_NOT_EXIST,
#     407     )
#     408 meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#     409 meta["tags"] = self.get_all_experiment_tags(experiment_id)
#
# MlflowException: Could not find experiment with ID 4109062141857899923

# %%
try:
    experiment = mlflow.get_experiment(experiment_id=experiment.experiment_id+"3")
except mlflow.exceptions.MlflowException as e:
    print(e)
# Out:
# Could not find experiment with ID 4109062141857899923

# %% [markdown]
# ### Get Experiment by name
#
# `get_experiment_by_name(name: str) → Optional[Experiment]`
#
# Retrieve an experiment by experiment name from the backend store
#
# Parameters:
#
# * name – The case sensitive experiment name.
#
# Returns:
#
# * An instance of mlflow.entities.Experiment if an experiment with the specified name exists, otherwise None.

# %%
experiment = mlflow.get_experiment_by_name(name=experiment_name)

# %%
print(f"Name: {experiment.name}")
print(f"Artifact Location: {experiment.artifact_location}")
print(f"Tags: {experiment.tags}")
print(f"Lifecycle_stage: {experiment.lifecycle_stage}")
print(f"Creation timestamp: {experiment.creation_time}")
# Out:
# Name: 02-mlflow_experiment_management
# Artifact Location: file:///C:/Users/manue/projects/mlflow_for_ml_dev/experiments/mlruns/410906214185789992
# Tags: {'project_name': 'UNKNOWN', 'topic': 'experiment_management'}
# Lifecycle_stage: active
# Creation timestamp: 1720966276150

# %%
experiment = mlflow.get_experiment_by_name(name=experiment_name+"some")

# %%
print(experiment)
# Out:
# None

# %%
if experiment:
    print(f"Name: {experiment.name}")
    print(f"Artifact Location: {experiment.artifact_location}")
    print(f"Tags: {experiment.tags}")
    print(f"Lifecycle_stage: {experiment.lifecycle_stage}")
    print(f"Creation timestamp: {experiment.creation_time}")
else:
    print("Experiment not found")
# Out:
# Experiment not found

# %% [markdown]
# ## Clean Up

# %%
experiments = mlflow.search_experiments(filter_string="name LIKE '02-mlflow%'")
for experiment in experiments:
    print(f"Deleting: {experiment.name}")
    mlflow.delete_experiment(experiment.experiment_id)
# Out:
# Deleting: 02-mlflow_experiment_management
