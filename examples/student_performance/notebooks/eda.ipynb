# %% [markdown]
# # Student Performance dataset

# %%
from examples.student_performance.src.data_processing import create_training_and_testing_dataset

# %%
df = create_training_and_testing_dataset()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a pairplot
features = ["Age", "Gender", "Ethnicity","ParentalEducation","StudyTimeWeekly", "Absences", "Tutoring","ParentalSupport", "Extracurricular", "Sports","Music", "Volunteering", "GPA", "GradeClass"]
sns.pairplot(df[features])
plt.show()

# %%
# Create a heatmap
df["Gender"].value_counts()
# Out:
# Gender
# 1    1222
# 0    1170
# Name: count, dtype: int64

# %%
df["Ethnicity"].value_counts()
# Out:
# Ethnicity
# 0    1207
# 1     493
# 2     470
# 3     222
# Name: count, dtype: int64

# %%
df["ParentalEducation"].value_counts()
# Out:
# ParentalEducation
# 2    934
# 1    728
# 3    367
# 0    243
# 4    120
# Name: count, dtype: int64

# %%
df["Tutoring"].value_counts()
# Out:
# Tutoring
# 0    1671
# 1     721
# Name: count, dtype: int64

# %%
df["ParentalSupport"].value_counts()
# Out:
# ParentalSupport
# 2    740
# 3    697
# 1    489
# 4    254
# 0    212
# Name: count, dtype: int64

# %%
df["Extracurricular"].value_counts()
# Out:
# Extracurricular
# 0    1475
# 1     917
# Name: count, dtype: int64

# %%
df["Sports"].value_counts()
# Out:
# Sports
# 0    1666
# 1     726
# Name: count, dtype: int64

# %%
df["Music"].value_counts()
# Out:
# Music
# 0    1921
# 1     471
# Name: count, dtype: int64

# %%
df["Volunteering"].value_counts()
# Out:
# Volunteering
# 0    2016
# 1     376
# Name: count, dtype: int64

# %%
df["GradeClass"].value_counts()
# Out:
# GradeClass
# 4.0    1211
# 3.0     414
# 2.0     391
# 1.0     269
# 0.0     107
# Name: count, dtype: int64

# %%
categorical_columns = ["Gender", "Ethnicity", "ParentalEducation", "Tutoring", "ParentalSupport", "Extracurricular", "Sports", "Music", "Volunteering"]
numerical_columns = ["Age", "StudyTimeWeekly", "Absences", "GPA"]

# %%
# plot study time weekly vs grade class
sns.boxplot(x="GradeClass", y="StudyTimeWeekly", data=df)
plt.show()

# %%
# plot study time weekly vs grade class
sns.boxplot(x="GradeClass", y="ParentalSupport", data=df)
plt.show()
